# %%
import cv2
from pathlib import Path
import os
import pandas as pd
import numpy as np
import shutil

# %%
p_img_file = Path('../src/data/explorationroom_largest_sampled.val')
with p_img_file.open('r') as img_f:
    for img in [x.rstrip() for x in img_f.readlines()]:
        img = Path(img)
        out = img.parent.parent / 'labels_with_ids' / img.name
        out = out.with_suffix('.txt')
        print(out)
        
        out.touch()
# Out:
# /media/hdd2/matthias/datasets/explorationroom_largest/validation/labels_with_ids/hum_20092021_M1-1_cam19415032_8225.txt
# /media/hdd2/matthias/datasets/explorationroom_largest/validation/labels_with_ids/hum_21092021_M1-1_cam19415032_64715.txt
# /media/hdd2/matthias/datasets/explorationroom_largest/validation/labels_with_ids/hum_21092021_M1-2_cam19415032_21805.txt
# /media/hdd2/matthias/datasets/explorationroom_largest/validation/labels_with_ids/hum_23092021_SMA-2_cam19415032_32200.txt
# /media/hdd2/matthias/datasets/explorationroom_largest/validation/labels_with_ids/hum_22092021_PMd-1_2_cam19415032_23240.txt
# /media/hdd2/matthias/datasets/explorationroom_largest/validation/labels_with_ids/hum_22092021_PMd-1_2_cam19415032_6755.txt
# /media/hdd2/matthias/datasets/explorationroom_largest/validation/labels_with_ids/hum_22092021_PMd-1_2_cam19415032_11060.txt
# /media/hdd2/matthias/datasets/explorationroom_largest/validation/labels_with_ids/hum_22092021_PMd-1_2_cam19415032_9135.txt
# ...
