# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import os.path as osp
import sys

# %%
#sys.path.insert(0, '/usr/users/vogg/FairMOT/src')
#sys.path.insert(0, '/usr/users/vogg/FairMOT/src/lib')
#sys.path.insert(0, '/opt/conda/envs/FairMOT/lib/python3.8/site-packages')
#sys.path.insert(0, '/usr/users/vogg/FairMOT/DCNv2')
sys.path
# Out:
# ['/usr/users/vogg/FairMOT/DCNv2',
#  '/opt/conda/envs/FairMOT/lib/python3.8/site-packages',
#  '/usr/users/vogg/FairMOT/src/lib',
#  '/usr/users/vogg/FairMOT/src',
#  '/usr/users/vogg/FairMOT/own_ideas',
#  '/opt/conda/lib/python38.zip',
#  '/opt/conda/lib/python3.8',
#  '/opt/conda/lib/python3.8/lib-dynload',
#  '',
#  '/opt/conda/lib/python3.8/site-packages',
#  '/opt/conda/lib/python3.8/site-packages/IPython/extensions',
#  '/home/vogg/.ipython']

# %%
import logging
import os
import re
import motmetrics as mm
import matplotlib.pyplot as plt
import numpy as np
import cv2
from adjustText import adjust_text
import torch.nn.functional as F

import _init_paths
from opts import opts
from models.model import create_model, load_model
from models.decode import mot_decode, _nms, _topk
from tracking_utils.utils import *
from tracking_utils.log import logger
from tracking_utils.kalman_filter import KalmanFilter
from models import *
from tracker import matching
from tracker.basetrack import BaseTrack, TrackState
from tracker.multitracker import STrack
from utils.post_process import ctdet_post_process
from utils.image import get_affine_transform
from models.utils import _tranpose_and_gather_feat
from datasets.jde import letterbox

# %% [markdown]
# ### Useful functions

# %%
def post_process(dets, meta):
    dets = dets.detach().cpu().numpy()
    dets = dets.reshape(1, -1, dets.shape[2])
    dets = ctdet_post_process(
        dets.copy(), [meta['c']], [meta['s']],
        meta['out_height'], meta['out_width'], 1)
    for j in range(1, 1 + 1):
        dets[0][j] = np.array(dets[0][j], dtype=np.float32).reshape(-1, 5)
    return dets[0]

def merge_outputs(detections):
    results = {}
    for j in range(1, 2):
        results[j] = np.concatenate(
            [detection[j] for detection in detections], axis=0).astype(np.float32)

    scores = np.hstack(
        [results[j][:, 4] for j in range(1, 2)])
    if len(scores) > 50:
        kth = len(scores) - 50
        thresh = np.partition(scores, kth)[kth]
        for j in range(1, 2):
            keep_inds = (results[j][:, 4] >= thresh)
            results[j] = results[j][keep_inds]
    return results

def get_info(frame_num, heatmap_thres = 0.1):
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_num)
    ret, img0 = cap.read()
    
    # Scale and fill grey borders
    img_box, _, _, _ = letterbox(img0, height=608, width=1088)

    # Normalize RGB
    img = img_box[:, :, ::-1].transpose(2, 0, 1)
    img = np.ascontiguousarray(img, dtype=np.float32)
    img /= 255.0

    im_blob = torch.from_numpy(img).cuda().unsqueeze(0)

    width = img0.shape[1]
    height = img0.shape[0]
    inp_height = im_blob.shape[2]
    inp_width = im_blob.shape[3]
    c = np.array([width / 2., height / 2.], dtype=np.float32)
    s = max(float(inp_width) / float(inp_height) * height, width) * 1.0
    meta = {'c': c, 's': s,
            'out_height': inp_height // 4,
            'out_width': inp_width // 4}
    
    with torch.no_grad():
        output = model(im_blob)[-1]
        hm = output['hm'].sigmoid_()
        wh = output['wh']
        id_feature = output['id']
        id_feature = F.normalize(id_feature, dim=1)
        reg = output['reg']

    dets, inds = mot_decode(hm, wh, reg=reg, ltrb=True, K=50)
    
    #find features to the IDs which were detected
    id_feature = _tranpose_and_gather_feat(id_feature, inds)
    id_feature = id_feature.squeeze(0)
    id_feature = id_feature.cpu().numpy()
    
    dets = post_process(dets, meta)
    dets = merge_outputs([dets])[1]

    # remove detections below the threshold

    remain_inds = dets[:, 4] > heatmap_thres
    dets = dets[remain_inds]
    inds = inds[:,remain_inds].cpu().numpy().squeeze()
    id_feature = id_feature[remain_inds]

    return img_box, hm, dets, inds, id_feature

def plot_frame(img, hm = None, top_preds = False, thres = 0.01, text = False):
    
    fig, ax = plt.subplots(figsize=(12, 7))
    if img is not None:
        ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    if hm is not None:
        hm_local = hm.cpu()
        hm2 = _nms(hm_local)

        scores, inds, clses, ys, xs = _topk(hm2, K = 50)
        hm_local = F.interpolate(hm_local, scale_factor = 4)
        hm_local = torch.squeeze(hm_local)
        
        hm_alpha = 0.5 if img is not None else 1
        ax.imshow(hm_local, alpha = hm_alpha)
    if top_preds:
        ax.scatter(xs[scores > thres] * 4, ys[scores > thres] * 4, s = 2, c = "red")
        for x, y, txt in zip(xs[scores > thres], ys[scores > thres], inds[scores > thres].numpy()):
            ax.text(x * 4, y * 4 ,txt, c = "white")

# %% [markdown]
# ### Load model

# %%
model = create_model('dla_34', heads =  {'hm': 1, 'wh': 4, 'id': 128, 'reg': 2}, 
                     head_conv = 256)

# %%
model = load_model(model, '../models/mcqcp/mcqcp10.pth')
model = model.to(torch.device('cuda'))
model.eval()
print('ok')
# Out:
# loaded ../models/mcqcp/mcqcp10.pth, epoch 10
# ok

# %% [markdown]
# ### Load video

# %%
cap = cv2.VideoCapture("/usr/users/agecker/datasets/macaque_videos/Videos/VID_20210223_123817_0.mp4")

# %% [markdown]
# Get any frame from the video.

# %% [markdown]
# ### Check Heatmap before and after NMS

# %%
img, hm, dets, inds, id_feature = get_info(137, 0.4)
plot_frame(img, hm, top_preds = True, thres = 0.4)

# %%
img1, hm1, dets1, inds1, id_feature1 = get_info(155, 0.004)
plot_frame(img1, hm1, top_preds = True, thres = 0.004)

# %% [markdown]
# ### Distance matrices
#
# First, we will get prior detections from the frame before.

# %%
kalman_filter = KalmanFilter()
tracks = []

detections = [STrack(STrack.tlbr_to_tlwh(tlbrs[:4]), tlbrs[4], f, 30) for
                          (tlbrs, f) in zip(dets[:, :5], id_feature)]

for track in detections:
    print(track.score)
    #if track.score < 0.4:
    #    continue
    track.activate(kalman_filter, 0)
    tracks.append(track)


STrack.multi_predict(tracks)
# Out:
# 0.9241568
# 0.9122809
# 0.89381075
# 0.8738427
# 0.8121421

# %%
detections1 = [STrack(STrack.tlbr_to_tlwh(tlbrs[:4]), tlbrs[4], f, 30) for
                          (tlbrs, f) in zip(dets1[:, :5], id_feature1)]

for track in detections1:
    print(track.score)
# Out:
# 0.9788278
# 0.9651563
# 0.9589207
# 0.9406084
# 0.07740797
# 0.006207034
# 0.0048481007
# 0.0040325546

# %%
emb_dists = matching.embedding_distance(detections1, tracks)

fig, ax = plt.subplots(figsize = (10, 5))
surf = plt.pcolormesh(emb_dists)
plt.colorbar(surf)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
for y, ind in enumerate(inds1):
    ax.text(-0.5, y, ind)
    max_y = y
    
for x, ind in enumerate(inds):
    ax.text(x, max_y + 1.2, ind)

# %%
iou_dists = matching.iou_distance(detections1, tracks)

fig, ax = plt.subplots(figsize = (10, 5))
surf = plt.pcolormesh(iou_dists)
plt.colorbar(surf)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
for y, ind in enumerate(inds1):
    ax.text(-0.5, y, ind)
    max_y = y
    
for x, ind in enumerate(inds):
    ax.text(x, max_y + 1.2, ind)

# %%
np.amin(dists, axis = 0)
# Out:
# array([    0.13316,    0.036159,     0.17268,     0.33933,     0.25731])

# %%
dists = np.multiply(2 * emb_dists, iou_dists)

print(dists)

fig, ax = plt.subplots(figsize = (10, 5))
surf = plt.pcolormesh(dists)

for y in range(dists.shape[0]):
    for x in range(dists.shape[1]):
        plt.text(x + 0.5, y + 0.5, '%.2f' % dists[y, x],
                 horizontalalignment='center',
                 verticalalignment='center',
                 )
        
plt.colorbar(surf)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
for y, ind in enumerate(inds1):
    ax.text(-0.5, y, ind)
    max_y = y
    
for x, ind in enumerate(inds):
    ax.text(x, max_y + 1.2, ind)
# Out:
# [[     1.2238      1.7658     0.17268      2.0005      1.9161]
#  [      1.134    0.036159      1.4821       1.644      1.8359]
#  [    0.13316     0.99712     0.84202      1.9171       2.012]
#  [     1.9748      1.9241      2.0157     0.33933     0.60804]
#  [     2.0636       2.026      2.0879     0.68327     0.25731]
#  [     2.3465      2.3209      2.1991      1.6863      1.5004]
#  [     1.9446      1.8611      1.9698      1.9367      1.9743]
#  [     2.3651      2.1707      2.0157      2.1037      1.5022]]

# %% [markdown]
# ### Visualize Embeddings

# %%
det = 32471 # for which object
track = 31925 # compare with which prior track

i = int(np.where(inds1 == det)[0])
j = int(np.where(inds == track)[0])
# Out:
# 0

# %%
fig, (ax1, ax2) = plt.subplots(2,1,figsize=(10, 1))

ax2.pcolormesh(id_feature1[i:(i+1),:])
ax1.pcolormesh(id_feature[j:(j+1),:])

# %% [markdown]
# ### Visualize Kalman Filter
#
# We need the distance matrix from above.

# %%
matches, u_track, u_detection = matching.linear_assignment(dists, thresh=0.6)

print(tracks[1].mean)

for itracked, idet in matches:
    print(itracked)
    track = tracks[itracked]
    det = detections1[idet]
    if track.state == TrackState.Tracked:
        track.update(det, 1)
        tracks.append(track)
    else:
        track.re_activate(det, self.frame_id, new_id=False)
        refind_stracks.append(track)
        
print(tracks[1].mean)
# Out:
# [     1318.1      438.18     0.65319       356.6           0           0           0           0]
# 0
# 1
# 2
# 3
# 4
# [     1299.7      475.69     0.65303      353.27     -4.3825       8.931 -8.0124e-11     -0.7944]

# %%
tracks[1].covariance
# Out:
# array([[     275.87,           0,           0,           0,      65.684,           0,           0,           0],
#        [          0,      275.87,           0,           0,           0,      65.684,           0,           0],
#        [          0,           0,  0.00019608,           0,           0,           0,  9.8039e-11,           0],
#        [          0,           0,           0,      275.87,           0,           0,           0,      65.684],
#        [     65.684,           0,           0,           0,      399.07,           0,           0,           0],
#        [          0,      65.684,           0,           0,           0,      399.07,           0,           0],
#        [          0,           0,  9.8039e-11,           0,           0,           0,       2e-10,           0],
#        [          0,           0,           0,      65.684,           0,           0,           0,      399.07]])
